# %%
import pandas as pd
df = pd.read_csv("customerdata4.csv")
df.describe()
# Out:
#        CustomerID         Age  Annual Income (10kkr)  Spending Score (1-100)
# count  200.000000  200.000000             200.000000              200.000000
# mean   100.500000   38.850000              60.560000               50.200000
# std     57.879185   13.969007              26.264721               25.823522
# min      1.000000   18.000000              15.000000                1.000000
# 25%     50.750000   28.750000              41.500000               34.750000
# 50%    100.500000   36.000000              61.500000               50.000000
# 75%    150.250000   49.000000              78.000000               73.000000
# max    200.000000   70.000000             137.000000               99.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("customerdata4.csv")
df.describe()

for col in ["Age", "Annual Income (10kkr)", "Spending Score (1-100)"]:
    df.boxplot(column=col, by="Gender")
    plt.title(f"{col} by Gender")
    plt.suptitle("")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
df = pd.read_csv("customerdata4.csv")

x = df [["Age", "Spending Score (1-100)"]]

plt.scatter(df["Age"], df["Spending Score (1-100)"])
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.title("Age vs Spending")
plt.show()

# %%
df = pd.read_csv("customerdata4.csv")

x = df [["Annual Income (10kkr)", "Spending Score (1-100)"]]
plt.scatter (df["Annual Income (10kkr)"], df["Spending Score (1-100)"])
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Annual Income vs Spending")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

df = pd.read_csv("Wholesale customers data.csv")

mu_cols = ["Fresh", "Milk", "Grocery", "Frozen", "Detergents_Paper", "Delicassen"]

display(df[mu_cols].head())

plt.figure(figsize=(12,6))
sns.boxplot(data=df[mu_cols])
plt.title("Boxplot of Annual Spending (monetary units)")
plt.xticks(rotation=45)
plt.show()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
df = pd.read_csv("Wholesale customers data.csv")

x = df [["Fresh", "Frozen"]]
plt.scatter (df["Fresh"], df["Frozen"])
plt.xlabel("Fresh")
plt.ylabel("Frozen")
plt.title("Fresh vs Frozen")
plt.show()

# %%
x = df [["Frozen", "Fresh"]].values

z = linkage(x, method = "ward")

plt.figure(figsize=(12,6))
dendrogram(z)
plt.title("Dendrogram")
plt.xlabel("Clients")
plt.ylabel("Distance")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

x = df[["Frozen", "Fresh"]]


agg = AgglomerativeClustering(n_clusters=2, linkage="ward")
labels = agg.fit_predict(x)

plt.scatter(x["Frozen"], x["Fresh"], c=labels)
plt.show()
